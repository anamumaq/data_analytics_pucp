# %% [markdown]
# <img src="https://www.python.org/static/img/python-logo.png" width="300" alt="Python logo"  />
# <font color='blue'>
# $\Large\text{Pontificia Universidad Católica del Perú}$</font>

# %% [markdown]
# $$\Large \textit{Estadística Aplicada}$$
#
# $$\large\textbf{Trabajo Clase 14: Regresión lineal multivariada}$$
#
# Nombe alumno:ANA MUÑOZ MAQUERA

# %% [markdown]
# Caso de estudio: **"Base financiera"**
#
# Haciendo uso de la base entregada desarrollar un modelo de regresión lineal multivariado / multiple usando como variable target el ingreso:
#
#
# Total de puntos (20 ptos)

# %%
import pandas as pd
import numpy as np


from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error


import statsmodels.api as sm
from statsmodels.formula.api import ols

# %% [markdown]
# ### **Paso 1**
# 1. Carga y muestreo.
#   *   Cargar la base de datos para la actividad.  **(1pto)**
#   *   Elegir las muestras de train y test con una proporción de 70% y 30%  **(2ptos)**

# %%
df = pd.read_csv('Base_financiera_1.csv', sep=';', index_col='ID')
df.sample(2)
# Out:
#        Edad Estado_civil     Genero Zona_geografica  Ingreso  \
# ID
# 10013    61       Casado  Masculino      LIMA NORTE     2500
# 2172     38      Soltero  Masculino    LIMA MODERNA    10500
#
#        Numero_entidades_sbs  Tenencia_Saldo_rcc  Tenencia_prestamos_rcc  \
# ID
# 10013                     5                   1                       1
# 2172                      3                   1                       0
#
#        Tenencia_hipotecario_rcc  Saldo_tc_rcc  ...  Antiguedad_pld  \
# ID                                             ...
# 10013                         0             0  ...               0
# 2172                          1             0  ...               0
#
#        Antiguedad_activos  Nro_meses_rcc  Tenencia_ahorros_6m  \
# ID
# 10013                   0             96                    1
# 2172                   47             97                    1
#
#        Tenencia_depo_plazo_6m  Tenencia_cts_6m  Tenencia_FFMM_6m  \
# ID
# 10013                       1                0                 1
# 2172                        0                1                 0
#
#        Nro_meses_visitaOficina_5M  cant_vecesvisitaoficina_5m  Target_mora
# ID
# 10013                           5                          17   SIN ATRASO
# 2172                            1                           1   SIN ATRASO
#
# [2 rows x 50 columns]

# %%
# Eligiendo la variable target
y = df['Ingreso']
x = df.drop(columns='Ingreso')

# Split the data
x_train, x_test, y_train, y_test = train_test_split(x, y, random_state=2023, test_size=0.30, shuffle=True)

# %% [markdown]
# ### **Paso 2**
# 2. Seleccionar un grupo de variables que sean adecuadas para el modelo. Describa los criterios o el método de selección utilizado **(3 ptos)**

# %% [markdown]
# #### Variables Categoricas
#
# * Como se hara un modelo de regresion decido utilizar solo las variables numericas. En caso necesite mas informacion podria dummisar las variables categoricaa para no eliminarlas
# * Dropeo las variables Estado_civil, Genero, Zona_geografica y Target_mora

# %%
x_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7450 entries, 6983 to 4952
# Data columns (total 49 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Edad                          7450 non-null   int64
#  1   Estado_civil                  7450 non-null   object
#  2   Genero                        7450 non-null   object
#  3   Zona_geografica               7450 non-null   object
#  4   Numero_entidades_sbs          7450 non-null   int64
#  5   Tenencia_Saldo_rcc            7450 non-null   int64
#  6   Tenencia_prestamos_rcc        7450 non-null   int64
#  7   Tenencia_hipotecario_rcc      7450 non-null   int64
#  8   Saldo_tc_rcc                  7450 non-null   int64
#  9   Saldo_prestamo_rcc            7450 non-null   int64
#  10  Saldo_hipotecario_rcc         7450 non-null   int64
#  11  deuda_rcc                     7450 non-null   int64
#  12  Tenencia_TC_rcc               7450 non-null   int64
#  13  Nro_bancos_tc_saldo           7450 non-null   int64
#  14  Cantidad_productos_rcc        7450 non-null   int64
#  15  Nro_bancos_pld                7450 non-null   int64
#  16  Nro_productos_activo_E1       7450 non-null   int64
#  17  Nro_productos_activo_E2       7450 non-null   int64
#  18  Nro_productos_activo_E3       7450 non-null   int64
#  19  Nro_productos_activo_E4       7450 non-null   int64
#  20  Nro_productos_activo_rcc      7450 non-null   int64
#  21  Antiguedad_cliente            7450 non-null   int64
#  22  Tenencia_ahorros              7450 non-null   int64
#  23  Tenencia_cts                  7450 non-null   int64
#  24  Tenencia_depo_plazo           7450 non-null   int64
#  25  Tenencia_FFMM                 7450 non-null   int64
#  26  Saldo_vehicular_prom          7450 non-null   int64
#  27  Saldo_hipot_prom              7450 non-null   int64
#  28  Flg_transacc_atm_3m           7450 non-null   int64
#  29  Flg_transacc_ventanilla_3m    7450 non-null   int64
#  30  Flg_transacc_bca_internet_3m  7450 non-null   int64
#  31  Flg_transacc_bca_telef_3m     7450 non-null   int64
#  32  Flg_ph                        7450 non-null   int64
#  33  Antiguedad_ph                 7450 non-null   int64
#  34  Antiguedad_ahorros            7450 non-null   int64
#  35  Antiguedad_depo_plazo         7450 non-null   int64
#  36  Antiguedad_cts                7450 non-null   int64
#  37  Antiguedad_pasivos            7450 non-null   int64
#  38  Nro_productos_pasivos         7450 non-null   int64
#  39  Antiguedad_pld                7450 non-null   int64
#  40  Antiguedad_activos            7450 non-null   int64
#  41  Nro_meses_rcc                 7450 non-null   int64
#  42  Tenencia_ahorros_6m           7450 non-null   int64
#  43  Tenencia_depo_plazo_6m        7450 non-null   int64
#  44  Tenencia_cts_6m               7450 non-null   int64
#  45  Tenencia_FFMM_6m              7450 non-null   int64
#  46  Nro_meses_visitaOficina_5M    7450 non-null   int64
#  47  cant_vecesvisitaoficina_5m    7450 non-null   int64
#  48  Target_mora                   7450 non-null   object
# dtypes: int64(45), object(4)
# memory usage: 2.8+ MB

# %%
# Eliminano columnas categoricas
x_train = x_train.drop(columns=['Estado_civil', 'Genero', 'Zona_geografica', 'Target_mora'], axis=1)

# %% [markdown]
# #### Variables altamente correlacionadas
#
# * Analizo las correlaciones y elimino las que son mayores a 0.9

# %%
# Evaluo correlaciones
corr = x_train.corr()
corr
# Out:
#                                   Edad  Numero_entidades_sbs  \
# Edad                          1.000000             -0.178377
# Numero_entidades_sbs         -0.178377              1.000000
# Tenencia_Saldo_rcc           -0.218894              0.576283
# Tenencia_prestamos_rcc       -0.133144              0.245118
# Tenencia_hipotecario_rcc     -0.265772              0.244414
# Saldo_tc_rcc                 -0.030367              0.067569
# Saldo_prestamo_rcc           -0.028021              0.036469
# Saldo_hipotecario_rcc        -0.030656              0.032137
# deuda_rcc                    -0.025430              0.046428
# Tenencia_TC_rcc              -0.218308              0.549855
# Nro_bancos_tc_saldo          -0.123750              0.918498
# Cantidad_productos_rcc       -0.289153              0.544628
# Nro_bancos_pld               -0.124979              0.283914
# Nro_productos_activo_E1      -0.203665              0.400677
# Nro_productos_activo_E2      -0.079917              0.421921
# Nro_productos_activo_E3      -0.122245              0.490522
# Nro_productos_activo_E4      -0.171865              0.394690
# Nro_productos_activo_rcc     -0.289153              0.544628
# Antiguedad_cliente            0.231492              0.246169
# Tenencia_ahorros             -0.055094              0.036382
# Tenencia_cts                 -0.096292              0.032035
# Tenencia_depo_plazo           0.150459             -0.082018
# Tenencia_FFMM                 0.104178             -0.082136
# Saldo_vehicular_prom         -0.005169              0.018983
# Saldo_hipot_prom             -0.046897              0.035998
# Flg_transacc_atm_3m          -0.116800              0.054812
# Flg_transacc_ventanilla_3m   -0.187559              0.200774
# Flg_transacc_bca_internet_3m -0.226984              0.114407
# Flg_transacc_bca_telef_3m    -0.106309              0.109383
# Flg_ph                       -0.061724             -0.003816
# Antiguedad_ph                -0.021929              0.003295
# Antiguedad_ahorros            0.099118              0.033783
# Antiguedad_depo_plazo         0.144768             -0.061501
# Antiguedad_cts               -0.026550              0.027842
# Antiguedad_pasivos            0.099735              0.038981
# Nro_productos_pasivos        -0.085443              0.054960
# Antiguedad_pld               -0.071045              0.067325
# Antiguedad_activos           -0.131903              0.125126
# Nro_meses_rcc                -0.024157              0.453881
# Tenencia_ahorros_6m           0.061800             -0.166882
# Tenencia_depo_plazo_6m        0.275327             -0.151041
# Tenencia_cts_6m              -0.148601              0.012892
# Tenencia_FFMM_6m              0.191457             -0.136695
# Nro_meses_visitaOficina_5M   -0.176381              0.183502
# cant_vecesvisitaoficina_5m   -0.104252              0.090188
#
#                               Tenencia_Saldo_rcc  Tenencia_prestamos_rcc  \
# Edad                                   -0.218894               -0.133144
# Numero_entidades_sbs                    0.576283                0.245118
# Tenencia_Saldo_rcc                      1.000000                0.204230
# Tenencia_prestamos_rcc                  0.204230                1.000000
# Tenencia_hipotecario_rcc                0.226067                0.125703
# Saldo_tc_rcc                            0.038408                0.057172
# Saldo_prestamo_rcc                      0.017356                0.058462
# Saldo_hipotecario_rcc                   0.022327               -0.000888
# deuda_rcc                              -0.007324                0.016861
# Tenencia_TC_rcc                         0.637287                0.152844
# Nro_bancos_tc_saldo                     0.622180                0.175809
# Cantidad_productos_rcc                  0.647840                0.577411
# Nro_bancos_pld                          0.250175                0.859320
# Nro_productos_activo_E1                 0.452168                0.326498
# Nro_productos_activo_E2                 0.338530                0.220165
# Nro_productos_activo_E3                 0.378538                0.229873
# Nro_productos_activo_E4                 0.423035                0.265965
# Nro_productos_activo_rcc                0.647840                0.577411
# Antiguedad_cliente                      0.232334                0.021222
# Tenencia_ahorros                        0.049203               -0.015251
# Tenencia_cts                            0.076789                0.024423
# Tenencia_depo_plazo                    -0.076763               -0.074088
# Tenencia_FFMM                          -0.082541               -0.067811
# Saldo_vehicular_prom                    0.015531               -0.003859
# Saldo_hipot_prom                        0.030918                0.018925
# Flg_transacc_atm_3m                     0.098316                0.044965
# Flg_transacc_ventanilla_3m              0.163026                0.109822
# Flg_transacc_bca_internet_3m            0.200851                0.029632
# Flg_transacc_bca_telef_3m               0.142476                0.030115
# Flg_ph                                  0.021361                0.041824
# Antiguedad_ph                           0.026318                0.031097
# Antiguedad_ahorros                      0.039615               -0.021665
# Antiguedad_depo_plazo                  -0.054525               -0.062321
# Antiguedad_cts                          0.064413                0.029781
# Antiguedad_pasivos                      0.060505               -0.006722
# Nro_productos_pasivos                   0.076713                0.019011
# Antiguedad_pld                          0.093727                0.402730
# Antiguedad_activos                      0.120924                0.150008
# Nro_meses_rcc                           0.357321                0.120501
# Tenencia_ahorros_6m                    -0.121266               -0.070202
# Tenencia_depo_plazo_6m                 -0.135889               -0.123512
# Tenencia_cts_6m                         0.077798                0.028515
# Tenencia_FFMM_6m                       -0.128834               -0.092620
# Nro_meses_visitaOficina_5M              0.137822                0.113719
# cant_vecesvisitaoficina_5m              0.051142                0.080781
#
#                               Tenencia_hipotecario_rcc  Saldo_tc_rcc  \
# Edad                                         -0.265772     -0.030367
# Numero_entidades_sbs                          0.244414      0.067569
# Tenencia_Saldo_rcc                            0.226067      0.038408
# Tenencia_prestamos_rcc                        0.125703      0.057172
# Tenencia_hipotecario_rcc                      1.000000      0.053067
# Saldo_tc_rcc                                  0.053067      1.000000
# Saldo_prestamo_rcc                            0.019070      0.275544
# Saldo_hipotecario_rcc                         0.078440      0.157034
# deuda_rcc                                     0.020368      0.588583
# Tenencia_TC_rcc                               0.182222      0.046545
# Nro_bancos_tc_saldo                           0.178063      0.024186
# Cantidad_productos_rcc                        0.559155      0.074492
# Nro_bancos_pld                                0.120146      0.096128
# Nro_productos_activo_E1                       0.362004      0.024107
# Nro_productos_activo_E2                       0.172752      0.027906
# Nro_productos_activo_E3                       0.218544      0.036892
# Nro_productos_activo_E4                       0.324727      0.054615
# Nro_productos_activo_rcc                      0.559155      0.074492
# Antiguedad_cliente                            0.023438      0.014945
# Tenencia_ahorros                              0.035854     -0.024614
# Tenencia_cts                                  0.045183      0.006362
# Tenencia_depo_plazo                          -0.124300     -0.021327
# Tenencia_FFMM                                -0.133179     -0.032822
# Saldo_vehicular_prom                          0.036345     -0.002489
# Saldo_hipot_prom                              0.204588      0.001745
# Flg_transacc_atm_3m                          -0.012033      0.000084
# Flg_transacc_ventanilla_3m                    0.097050      0.032836
# Flg_transacc_bca_internet_3m                  0.113889     -0.005153
# Flg_transacc_bca_telef_3m                     0.037185      0.009069
# Flg_ph                                        0.002272     -0.001899
# Antiguedad_ph                                 0.009761      0.000985
# Antiguedad_ahorros                            0.005462     -0.004451
# Antiguedad_depo_plazo                        -0.082146     -0.013422
# Antiguedad_cts                                0.037614      0.017643
# Antiguedad_pasivos                            0.010939      0.001281
# Nro_productos_pasivos                         0.037619      0.001995
# Antiguedad_pld                                0.065202      0.039940
# Antiguedad_activos                            0.482605      0.056831
# Nro_meses_rcc                                 0.123274      0.030586
# Tenencia_ahorros_6m                          -0.045206     -0.023490
# Tenencia_depo_plazo_6m                       -0.160269     -0.037553
# Tenencia_cts_6m                               0.050826      0.008423
# Tenencia_FFMM_6m                             -0.152474     -0.037074
# Nro_meses_visitaOficina_5M                    0.094967      0.010771
# cant_vecesvisitaoficina_5m                    0.050775     -0.004647
#
#                               Saldo_prestamo_rcc  Saldo_hipotecario_rcc  \
# Edad                                   -0.028021              -0.030656
# Numero_entidades_sbs                    0.036469               0.032137
# Tenencia_Saldo_rcc                      0.017356               0.022327
# Tenencia_prestamos_rcc                  0.058462              -0.000888
# Tenencia_hipotecario_rcc                0.019070               0.078440
# Saldo_tc_rcc                            0.275544               0.157034
# Saldo_prestamo_rcc                      1.000000               0.126371
# Saldo_hipotecario_rcc                   0.126371               1.000000
# deuda_rcc                               0.294424               0.189184
# Tenencia_TC_rcc                         0.013095               0.016843
# Nro_bancos_tc_saldo                    -0.002838               0.002955
# Cantidad_productos_rcc                  0.032914               0.037953
# Nro_bancos_pld                          0.131924              -0.000810
# Nro_productos_activo_E1                 0.008861               0.039738
# Nro_productos_activo_E2                 0.010962              -0.007672
# Nro_productos_activo_E3                 0.011028               0.009714
# Nro_productos_activo_E4                 0.009434              -0.012218
# Nro_productos_activo_rcc                0.032914               0.037953
# Antiguedad_cliente                      0.003523               0.009451
# Tenencia_ahorros                       -0.025188              -0.035353
# Tenencia_cts                           -0.005809              -0.018917
# Tenencia_depo_plazo                    -0.020057              -0.018663
# Tenencia_FFMM                          -0.019767              -0.017054
# Saldo_vehicular_prom                    0.010727               0.007386
# Saldo_hipot_prom                        0.003877               0.055608
# Flg_transacc_atm_3m                     0.001071              -0.040010
# Flg_transacc_ventanilla_3m              0.014990               0.018066
# Flg_transacc_bca_internet_3m            0.003016              -0.021819
# Flg_transacc_bca_telef_3m               0.011967              -0.008414
# Flg_ph                                  0.017350              -0.017971
# Antiguedad_ph                           0.026037              -0.013861
# Antiguedad_ahorros                      0.004687               0.010435
# Antiguedad_depo_plazo                  -0.014224              -0.011626
# Antiguedad_cts                         -0.004634              -0.009821
# Antiguedad_pasivos                     -0.002275               0.006720
# Nro_productos_pasivos                   0.003008              -0.002175
# Antiguedad_pld                          0.071274               0.030119
# Antiguedad_activos                      0.061779               0.106827
# Nro_meses_rcc                           0.006862               0.002029
# Tenencia_ahorros_6m                    -0.016343              -0.041522
# Tenencia_depo_plazo_6m                 -0.036519              -0.022016
# Tenencia_cts_6m                         0.004343               0.005220
# Tenencia_FFMM_6m                       -0.031958              -0.030171
# Nro_meses_visitaOficina_5M              0.015459               0.021911
# cant_vecesvisitaoficina_5m             -0.008367               0.007909
#
#                               deuda_rcc  Tenencia_TC_rcc  ...  \
# Edad                          -0.025430        -0.218308  ...
# Numero_entidades_sbs           0.046428         0.549855  ...
# Tenencia_Saldo_rcc            -0.007324         0.637287  ...
# Tenencia_prestamos_rcc         0.016861         0.152844  ...
# Tenencia_hipotecario_rcc       0.020368         0.182222  ...
# Saldo_tc_rcc                   0.588583         0.046545  ...
# Saldo_prestamo_rcc             0.294424         0.013095  ...
# Saldo_hipotecario_rcc          0.189184         0.016843  ...
# deuda_rcc                      1.000000         0.003625  ...
# Tenencia_TC_rcc                0.003625         1.000000  ...
# Nro_bancos_tc_saldo           -0.018875         0.606175  ...
# Cantidad_productos_rcc         0.026125         0.585946  ...
# Nro_bancos_pld                 0.061228         0.231998  ...
# Nro_productos_activo_E1       -0.004675         0.393161  ...
# Nro_productos_activo_E2       -0.000004         0.249497  ...
# Nro_productos_activo_E3        0.014707         0.286412  ...
# Nro_productos_activo_E4        0.014594         0.312486  ...
# Nro_productos_activo_rcc       0.026125         0.585946  ...
# Antiguedad_cliente            -0.013901         0.319811  ...
# Tenencia_ahorros              -0.016047         0.150850  ...
# Tenencia_cts                  -0.021265         0.089580  ...
# Tenencia_depo_plazo           -0.027135        -0.006353  ...
# Tenencia_FFMM                 -0.031606        -0.010418  ...
# Saldo_vehicular_prom           0.003964         0.019772  ...
# Saldo_hipot_prom               0.003595         0.018710  ...
# Flg_transacc_atm_3m           -0.027560         0.117332  ...
# Flg_transacc_ventanilla_3m     0.026751         0.186019  ...
# Flg_transacc_bca_internet_3m  -0.023907         0.191186  ...
# Flg_transacc_bca_telef_3m     -0.000540         0.114202  ...
# Flg_ph                        -0.007184         0.049873  ...
# Antiguedad_ph                 -0.007297         0.053525  ...
# Antiguedad_ahorros            -0.008414         0.136296  ...
# Antiguedad_depo_plazo         -0.017428         0.006688  ...
# Antiguedad_cts                -0.009825         0.066970  ...
# Antiguedad_pasivos            -0.010721         0.153430  ...
# Nro_productos_pasivos         -0.011548         0.190918  ...
# Antiguedad_pld                 0.011734         0.076983  ...
# Antiguedad_activos             0.038601         0.109280  ...
# Nro_meses_rcc                  0.013517         0.438313  ...
# Tenencia_ahorros_6m           -0.035740        -0.109319  ...
# Tenencia_depo_plazo_6m        -0.040699        -0.069025  ...
# Tenencia_cts_6m               -0.013799         0.074116  ...
# Tenencia_FFMM_6m              -0.038603        -0.072064  ...
# Nro_meses_visitaOficina_5M     0.009422         0.135090  ...
# cant_vecesvisitaoficina_5m     0.003284         0.060165  ...
#
#                               Nro_productos_pasivos  Antiguedad_pld  \
# Edad                                      -0.085443       -0.071045
# Numero_entidades_sbs                       0.054960        0.067325
# Tenencia_Saldo_rcc                         0.076713        0.093727
# Tenencia_prestamos_rcc                     0.019011        0.402730
# Tenencia_hipotecario_rcc                   0.037619        0.065202
# Saldo_tc_rcc                               0.001995        0.039940
# Saldo_prestamo_rcc                         0.003008        0.071274
# Saldo_hipotecario_rcc                     -0.002175        0.030119
# deuda_rcc                                 -0.011548        0.011734
# Tenencia_TC_rcc                            0.190918        0.076983
# Nro_bancos_tc_saldo                        0.056242        0.048375
# Cantidad_productos_rcc                     0.064486        0.241401
# Nro_bancos_pld                             0.014813        0.375775
# Nro_productos_activo_E1                    0.105292        0.373777
# Nro_productos_activo_E2                   -0.001317        0.052315
# Nro_productos_activo_E3                    0.005185        0.062243
# Nro_productos_activo_E4                   -0.057583       -0.006112
# Nro_productos_activo_rcc                   0.064486        0.241401
# Antiguedad_cliente                         0.277274        0.028855
# Tenencia_ahorros                           0.509572        0.043266
# Tenencia_cts                               0.575220        0.042032
# Tenencia_depo_plazo                        0.491380       -0.035273
# Tenencia_FFMM                              0.120636       -0.012524
# Saldo_vehicular_prom                       0.017453        0.032243
# Saldo_hipot_prom                           0.023251        0.023199
# Flg_transacc_atm_3m                        0.219146        0.052348
# Flg_transacc_ventanilla_3m                 0.168643        0.095998
# Flg_transacc_bca_internet_3m               0.165553        0.059406
# Flg_transacc_bca_telef_3m                  0.066455        0.044816
# Flg_ph                                     0.188052        0.032960
# Antiguedad_ph                              0.184545        0.037982
# Antiguedad_ahorros                         0.427076        0.061222
# Antiguedad_depo_plazo                      0.332958       -0.028213
# Antiguedad_cts                             0.437428        0.026146
# Antiguedad_pasivos                         0.495226        0.049839
# Nro_productos_pasivos                      1.000000        0.065203
# Antiguedad_pld                             0.065203        1.000000
# Antiguedad_activos                         0.088614        0.294695
# Nro_meses_rcc                              0.244186        0.029496
# Tenencia_ahorros_6m                        0.406381        0.039264
# Tenencia_depo_plazo_6m                     0.291891       -0.033053
# Tenencia_cts_6m                            0.424859        0.041420
# Tenencia_FFMM_6m                           0.122980       -0.010485
# Nro_meses_visitaOficina_5M                 0.122449        0.129125
# cant_vecesvisitaoficina_5m                 0.080530        0.110011
#
#                               Antiguedad_activos  Nro_meses_rcc  \
# Edad                                   -0.131903      -0.024157
# Numero_entidades_sbs                    0.125126       0.453881
# Tenencia_Saldo_rcc                      0.120924       0.357321
# Tenencia_prestamos_rcc                  0.150008       0.120501
# Tenencia_hipotecario_rcc                0.482605       0.123274
# Saldo_tc_rcc                            0.056831       0.030586
# Saldo_prestamo_rcc                      0.061779       0.006862
# Saldo_hipotecario_rcc                   0.106827       0.002029
# deuda_rcc                               0.038601       0.013517
# Tenencia_TC_rcc                         0.109280       0.438313
# Nro_bancos_tc_saldo                     0.083016       0.406369
# Cantidad_productos_rcc                  0.312454       0.335162
# Nro_bancos_pld                          0.145061       0.139030
# Nro_productos_activo_E1                 0.425688       0.194655
# Nro_productos_activo_E2                 0.038108       0.209551
# Nro_productos_activo_E3                 0.072959       0.199654
# Nro_productos_activo_E4                 0.024172       0.232967
# Nro_productos_activo_rcc                0.312454       0.335162
# Antiguedad_cliente                      0.056776       0.476379
# Tenencia_ahorros                        0.089367       0.195768
# Tenencia_cts                            0.035780       0.085347
# Tenencia_depo_plazo                    -0.065124       0.030034
# Tenencia_FFMM                          -0.063941       0.028031
# Saldo_vehicular_prom                    0.055840       0.010605
# Saldo_hipot_prom                        0.168307      -0.009792
# Flg_transacc_atm_3m                     0.030634       0.064326
# Flg_transacc_ventanilla_3m              0.108199       0.166407
# Flg_transacc_bca_internet_3m            0.088965       0.090374
# Flg_transacc_bca_telef_3m               0.035957       0.052577
# Flg_ph                                  0.031881       0.044490
# Antiguedad_ph                           0.044242       0.072463
# Antiguedad_ahorros                      0.135882       0.223496
# Antiguedad_depo_plazo                  -0.041962       0.024618
# Antiguedad_cts                          0.027294       0.104739
# Antiguedad_pasivos                      0.115159       0.246884
# Nro_productos_pasivos                   0.088614       0.244186
# Antiguedad_pld                          0.294695       0.029496
# Antiguedad_activos                      1.000000       0.069394
# Nro_meses_rcc                           0.069394       1.000000
# Tenencia_ahorros_6m                     0.036352      -0.117396
# Tenencia_depo_plazo_6m                 -0.077966      -0.046395
# Tenencia_cts_6m                         0.042666       0.065708
# Tenencia_FFMM_6m                       -0.069472      -0.057374
# Nro_meses_visitaOficina_5M              0.131656       0.083860
# cant_vecesvisitaoficina_5m              0.083778       0.037073
#
#                               Tenencia_ahorros_6m  Tenencia_depo_plazo_6m  \
# Edad                                     0.061800                0.275327
# Numero_entidades_sbs                    -0.166882               -0.151041
# Tenencia_Saldo_rcc                      -0.121266               -0.135889
# Tenencia_prestamos_rcc                  -0.070202               -0.123512
# Tenencia_hipotecario_rcc                -0.045206               -0.160269
# Saldo_tc_rcc                            -0.023490               -0.037553
# Saldo_prestamo_rcc                      -0.016343               -0.036519
# Saldo_hipotecario_rcc                   -0.041522               -0.022016
# deuda_rcc                               -0.035740               -0.040699
# Tenencia_TC_rcc                         -0.109319               -0.069025
# Nro_bancos_tc_saldo                     -0.145478               -0.092117
# Cantidad_productos_rcc                  -0.114734               -0.193167
# Nro_bancos_pld                          -0.067882               -0.123458
# Nro_productos_activo_E1                  0.010117               -0.090223
# Nro_productos_activo_E2                 -0.115036               -0.097054
# Nro_productos_activo_E3                 -0.110481               -0.120587
# Nro_productos_activo_E4                 -0.184948               -0.142229
# Nro_productos_activo_rcc                -0.114734               -0.193167
# Antiguedad_cliente                      -0.018383                0.152838
# Tenencia_ahorros                         0.712307                0.123128
# Tenencia_cts                             0.063662               -0.001684
# Tenencia_depo_plazo                      0.110111                0.573760
# Tenencia_FFMM                            0.147853                0.179532
# Saldo_vehicular_prom                     0.023663               -0.002315
# Saldo_hipot_prom                         0.025623               -0.048199
# Flg_transacc_atm_3m                      0.262181                0.001873
# Flg_transacc_ventanilla_3m               0.121112               -0.065680
# Flg_transacc_bca_internet_3m             0.166765               -0.011366
# Flg_transacc_bca_telef_3m                0.053064               -0.010831
# Flg_ph                                   0.144048               -0.002719
# Antiguedad_ph                            0.125817                0.013108
# Antiguedad_ahorros                       0.247612                0.229157
# Antiguedad_depo_plazo                    0.077157                0.383669
# Antiguedad_cts                           0.003539                0.000159
# Antiguedad_pasivos                       0.187450                0.210232
# Nro_productos_pasivos                    0.406381                0.291891
# Antiguedad_pld                           0.039264               -0.033053
# Antiguedad_activos                       0.036352               -0.077966
# Nro_meses_rcc                           -0.117396               -0.046395
# Tenencia_ahorros_6m                      1.000000                0.209783
# Tenencia_depo_plazo_6m                   0.209783                1.000000
# Tenencia_cts_6m                          0.173737                0.003059
# Tenencia_FFMM_6m                         0.238860                0.332480
# Nro_meses_visitaOficina_5M               0.139853               -0.043627
# cant_vecesvisitaoficina_5m               0.105253               -0.019279
#
#                               Tenencia_cts_6m  Tenencia_FFMM_6m  \
# Edad                                -0.148601          0.191457
# Numero_entidades_sbs                 0.012892         -0.136695
# Tenencia_Saldo_rcc                   0.077798         -0.128834
# Tenencia_prestamos_rcc               0.028515         -0.092620
# Tenencia_hipotecario_rcc             0.050826         -0.152474
# Saldo_tc_rcc                         0.008423         -0.037074
# Saldo_prestamo_rcc                   0.004343         -0.031958
# Saldo_hipotecario_rcc                0.005220         -0.030171
# deuda_rcc                           -0.013799         -0.038603
# Tenencia_TC_rcc                      0.074116         -0.072064
# Nro_bancos_tc_saldo                  0.039020         -0.097245
# Cantidad_productos_rcc               0.082966         -0.170535
# Nro_bancos_pld                       0.033632         -0.095150
# Nro_productos_activo_E1              0.082234         -0.061314
# Nro_productos_activo_E2              0.047799         -0.110676
# Nro_productos_activo_E3              0.028429         -0.118023
# Nro_productos_activo_E4              0.005674         -0.156896
# Nro_productos_activo_rcc             0.082966         -0.170535
# Antiguedad_cliente                   0.120765          0.083229
# Tenencia_ahorros                     0.095443          0.136788
# Tenencia_cts                         0.678078          0.011924
# Tenencia_depo_plazo                 -0.022947          0.154354
# Tenencia_FFMM                        0.003240          0.675692
# Saldo_vehicular_prom                 0.010683          0.002259
# Saldo_hipot_prom                    -0.003663         -0.043989
# Flg_transacc_atm_3m                  0.158745          0.026867
# Flg_transacc_ventanilla_3m           0.045771          0.029066
# Flg_transacc_bca_internet_3m         0.178770          0.031326
# Flg_transacc_bca_telef_3m            0.074330         -0.007026
# Flg_ph                               0.195618         -0.002185
# Antiguedad_ph                        0.195903          0.012937
# Antiguedad_ahorros                   0.131306          0.176144
# Antiguedad_depo_plazo               -0.018722          0.085514
# Antiguedad_cts                       0.531148         -0.001436
# Antiguedad_pasivos                   0.278529          0.146387
# Nro_productos_pasivos                0.424859          0.122980
# Antiguedad_pld                       0.041420         -0.010485
# Antiguedad_activos                   0.042666         -0.069472
# Nro_meses_rcc                        0.065708         -0.057374
# Tenencia_ahorros_6m                  0.173737          0.238860
# Tenencia_depo_plazo_6m               0.003059          0.332480
# Tenencia_cts_6m                      1.000000          0.043639
# Tenencia_FFMM_6m                     0.043639          1.000000
# Nro_meses_visitaOficina_5M           0.048845          0.056172
# cant_vecesvisitaoficina_5m           0.025588          0.087889
#
#                               Nro_meses_visitaOficina_5M  \
# Edad                                           -0.176381
# Numero_entidades_sbs                            0.183502
# Tenencia_Saldo_rcc                              0.137822
# Tenencia_prestamos_rcc                          0.113719
# Tenencia_hipotecario_rcc                        0.094967
# Saldo_tc_rcc                                    0.010771
# Saldo_prestamo_rcc                              0.015459
# Saldo_hipotecario_rcc                           0.021911
# deuda_rcc                                       0.009422
# Tenencia_TC_rcc                                 0.135090
# Nro_bancos_tc_saldo                             0.139747
# Cantidad_productos_rcc                          0.181447
# Nro_bancos_pld                                  0.118477
# Nro_productos_activo_E1                         0.301010
# Nro_productos_activo_E2                         0.046587
# Nro_productos_activo_E3                         0.093014
# Nro_productos_activo_E4                        -0.044535
# Nro_productos_activo_rcc                        0.181447
# Antiguedad_cliente                              0.025209
# Tenencia_ahorros                                0.199688
# Tenencia_cts                                    0.022364
# Tenencia_depo_plazo                            -0.039267
# Tenencia_FFMM                                   0.064202
# Saldo_vehicular_prom                            0.041406
# Saldo_hipot_prom                                0.038856
# Flg_transacc_atm_3m                             0.303486
# Flg_transacc_ventanilla_3m                      0.767382
# Flg_transacc_bca_internet_3m                    0.145078
# Flg_transacc_bca_telef_3m                       0.150026
# Flg_ph                                          0.109045
# Antiguedad_ph                                   0.104763
# Antiguedad_ahorros                              0.084970
# Antiguedad_depo_plazo                          -0.049012
# Antiguedad_cts                                 -0.020321
# Antiguedad_pasivos                              0.043124
# Nro_productos_pasivos                           0.122449
# Antiguedad_pld                                  0.129125
# Antiguedad_activos                              0.131656
# Nro_meses_rcc                                   0.083860
# Tenencia_ahorros_6m                             0.139853
# Tenencia_depo_plazo_6m                         -0.043627
# Tenencia_cts_6m                                 0.048845
# Tenencia_FFMM_6m                                0.056172
# Nro_meses_visitaOficina_5M                      1.000000
# cant_vecesvisitaoficina_5m                      0.655329
#
#                               cant_vecesvisitaoficina_5m
# Edad                                           -0.104252
# Numero_entidades_sbs                            0.090188
# Tenencia_Saldo_rcc                              0.051142
# Tenencia_prestamos_rcc                          0.080781
# Tenencia_hipotecario_rcc                        0.050775
# Saldo_tc_rcc                                   -0.004647
# Saldo_prestamo_rcc                             -0.008367
# Saldo_hipotecario_rcc                           0.007909
# deuda_rcc                                       0.003284
# Tenencia_TC_rcc                                 0.060165
# Nro_bancos_tc_saldo                             0.054633
# Cantidad_productos_rcc                          0.103207
# Nro_bancos_pld                                  0.075140
# Nro_productos_activo_E1                         0.196698
# Nro_productos_activo_E2                         0.023227
# Nro_productos_activo_E3                         0.041743
# Nro_productos_activo_E4                        -0.052349
# Nro_productos_activo_rcc                        0.103207
# Antiguedad_cliente                              0.009477
# Tenencia_ahorros                                0.133823
# Tenencia_cts                                    0.017837
# Tenencia_depo_plazo                            -0.021932
# Tenencia_FFMM                                   0.109415
# Saldo_vehicular_prom                            0.040960
# Saldo_hipot_prom                                0.022366
# Flg_transacc_atm_3m                             0.176558
# Flg_transacc_ventanilla_3m                      0.437024
# Flg_transacc_bca_internet_3m                    0.055619
# Flg_transacc_bca_telef_3m                       0.081246
# Flg_ph                                          0.037849
# Antiguedad_ph                                   0.038741
# Antiguedad_ahorros                              0.057760
# Antiguedad_depo_plazo                          -0.022499
# Antiguedad_cts                                 -0.015226
# Antiguedad_pasivos                              0.031096
# Nro_productos_pasivos                           0.080530
# Antiguedad_pld                                  0.110011
# Antiguedad_activos                              0.083778
# Nro_meses_rcc                                   0.037073
# Tenencia_ahorros_6m                             0.105253
# Tenencia_depo_plazo_6m                         -0.019279
# Tenencia_cts_6m                                 0.025588
# Tenencia_FFMM_6m                                0.087889
# Nro_meses_visitaOficina_5M                      0.655329
# cant_vecesvisitaoficina_5m                      1.000000
#
# [45 rows x 45 columns]

# %%
# Obteniendo correlaciones mayores a 0.9 y -0.9
corr = corr.where(np.tril(np.ones(corr.shape)).astype(np.bool))
corr = corr.unstack().dropna().sort_values(ascending=False)
corr = corr[corr!=1]

corre_high = corr[corr>=0.9]
corre_low = corr[corr<=-0.9]

# variables con alta correlacion
corre_high 
# Nro_productos_activo_rcc  y Cantidad_productos_rcc varibales con 1 de correlacion
#corre_low # vacio
# Out:
# <ipython-input-139-cff1476024df>:2: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   corr = corr.where(np.tril(np.ones(corr.shape)).astype(np.bool))
# Numero_entidades_sbs  Nro_bancos_tc_saldo    0.918498
# dtype: float64

# %%
# Drop variables altamente correlacionadas
x_train = x_train.drop(columns=['Nro_bancos_tc_saldo','Cantidad_productos_rcc'], axis=1)

# Columnas que quedan
print('Columas que quedan :', len(x_train.columns))
# Out:
# Columas que quedan : 43

# %% [markdown]
# #### Sequential Feature Selector
# * De las columnas que nos quedan elegimos solo el 50% paraprobar en el modelo y elegir las mejores

# %%
# from sklearn.feature_selection import SequentialFeatureSelector

# selector = SequentialFeatureSelector(
#     estimator=LinearRegression(), n_features_to_select=20,
#     direction='forward', cv=5, scoring='r2'
# )
# selector.fit(x_train,y_train)

# selected_forward = x_train.columns[selector.get_support()]
# columnas = selected_forward.sort_values().tolist()
# columnas

# %%
# Columnas elegidas para probar el modelo
x_train = x_train[columnas]
# Utilizando las columnas para el dataset de test
x_test = x_test[columnas]

# %% [markdown]
# ### **Paso 3**
# *   Entrenar el modelo en la subpoblación de train **(3ptos)**
# *   Analizar la significancia de las variables en el modelo elegido **(2ptos)**
# *   Elija 2 coeficientes del modelo de regresión e interpretelo **(2ptos)**
# *   Calcular e interpretar la métrica de bondad de ajuste para el modelo "R2_score" en los subgrupos de train y test (comparar) **(3ptos)**:

# %%
# Normalizando 
scaler = StandardScaler()
norm_x = scaler.fit(x_train)

# Dataset despues de la normalizacion
x_train_norm = norm_x.transform(x_train)
x_test_norm = norm_x.transform(x_test)

x_train = pd.DataFrame(x_train_norm, columns=x_train.columns)
x_test = pd.DataFrame(x_test_norm, columns=x_test.columns)

# # normalizando Ingresos
norm_y = scaler.fit(y_train.values.reshape(-1, 1))
y_train_norm = norm_y.transform(y_train.values.reshape(-1, 1))
y_test_norm = norm_y.transform(y_test.values.reshape(-1, 1))

y_train = pd.DataFrame(y_train_norm)#, columns=y_train.index)
y_test = pd.DataFrame(y_test_norm)#, #columns=y_test.index)

# %%
# entrenando el modelo en train
lr = LinearRegression()
lr_model = lr.fit(x_train, y_train)

# %%
# intercepto y coeficiente de variables

print('Intercepto: ', lr_model.intercept_)
print('Coeficiente: ' , list(zip(x_train.columns, lr_model.coef_.flatten())))
# Out:
# Intercepto:  [-9.98609623e-18]
# Coeficiente:  [('Antiguedad_activos', -0.006460743285714706), ('Antiguedad_depo_plazo', -0.018015138880811465), ('Antiguedad_pasivos', 0.019482906279878098), ('Antiguedad_ph', 0.0036883545687720534), ('Antiguedad_pld', -0.0017792012112640553), ('Nro_meses_rcc', 0.0023987068428283735), ('Nro_productos_activo_E3', -0.003809336160868708), ('Nro_productos_activo_E4', 0.04210298773709623), ('Numero_entidades_sbs', -0.005031063582008384), ('Saldo_hipotecario_rcc', -0.005656277944033607), ('Saldo_prestamo_rcc', 0.0006169790406974723), ('Saldo_tc_rcc', -0.014312023191529655), ('Tenencia_Saldo_rcc', 0.04631449791315687), ('Tenencia_TC_rcc', 0.018949593592884364), ('Tenencia_ahorros', 0.015571363033151254), ('Tenencia_ahorros_6m', -0.009073737186560024), ('Tenencia_cts_6m', 0.026836795632906578), ('Tenencia_hipotecario_rcc', 0.014542761160500243), ('cant_vecesvisitaoficina_5m', -0.01520871061697657), ('deuda_rcc', 0.0044939901403624055)]

# %%
# Lista de coeficientes del modelo entrenado
coef = list(zip(x_train.columns, lr_model.coef_.flatten()))

(pd.DataFrame(coef, columns = ['Variable', 'Coeficientes'])
.sort_values(by='Coeficientes', ascending=False)
)
# Out:
#                       Variable  Coeficientes
# 12          Tenencia_Saldo_rcc      0.046314
# 7      Nro_productos_activo_E4      0.042103
# 16             Tenencia_cts_6m      0.026837
# 2           Antiguedad_pasivos      0.019483
# 13             Tenencia_TC_rcc      0.018950
# 14            Tenencia_ahorros      0.015571
# 17    Tenencia_hipotecario_rcc      0.014543
# 19                   deuda_rcc      0.004494
# 3                Antiguedad_ph      0.003688
# 5                Nro_meses_rcc      0.002399
# 10          Saldo_prestamo_rcc      0.000617
# 4               Antiguedad_pld     -0.001779
# 6      Nro_productos_activo_E3     -0.003809
# 8         Numero_entidades_sbs     -0.005031
# 9        Saldo_hipotecario_rcc     -0.005656
# 0           Antiguedad_activos     -0.006461
# 15         Tenencia_ahorros_6m     -0.009074
# 11                Saldo_tc_rcc     -0.014312
# 18  cant_vecesvisitaoficina_5m     -0.015209
# 1        Antiguedad_depo_plazo     -0.018015

# %% [markdown]
# * Cada ingreso adicional se relaciona con **Tenencia_Saldo_rcc** en 0.04 en resumen la variable tiene un coeficiente de impacta de manera positiva a la regresion lineal
# * Por el lado de la **Tenencia_ahorros_6m** impacta de manera negativa al ingreso en -0.009

# %%
# Evaluando prediccion de test y train
y_pred_train = lr_model.predict(x_train)
y_pred_test = lr_model.predict(x_test)

r2_train = r2_score(y_train, y_pred_train)

r2_test = r2_score(y_test, y_pred_test)

print('R2 score train', r2_train)
print('R2 score test', r2_test)
# Out:
# R2 score train 0.010732744233844627
# R2 score test 0.020287672675749935

# %% [markdown]
# * Los resultados de R2 nos indicarian que el modelo de regresion lineal multiple no esta prediciendo bien la data train ni la data de test

# %% [markdown]
# ### **Paso 4**
#
# Desarrollar e interpretar cada uno de los siguientes análisis:
#
# *   Calcular el gráfico de residuales (Residual plot)  **(1pto)**
# *   Hacer la prueba de hipotesis para verificar la normalidad de los residuales **(1pto)**
# *   Hacer el análisis de homocedasticidad con el gráfico 'Fitted vs Residual' **(1pto)**
# *   Analizar la linealidad con el gráfico 'Fitted vs Observed' **(1pto)**

# %%
# Residuales
residual = (y_test - y_pred_test)

import matplotlib.pyplot as plt

plt.scatter(y_pred_test, residual)
plt.axhline(y=0, color='r', linestyle='-')
plt.xlabel('Valores ajustados')
plt.ylabel('Residuos')
plt.title('Gráfico de residuos')
plt.show()

# %% [markdown]
# * Nos permite visualizar si el modelo es adecuado para los datos, pero al parecer, los valores residuales no se estan distribuyendo aleatoreamente

# %%
# Normalidad de residuales

from scipy.stats import shapiro

# Realizar prueba de normalidad de Shapiro-Wilk
p_value = shapiro(residual)[1]

# Imprimir el valor p
print("Valor p: ", p_value)

# Verificar si los residuos son normales (nivel de significancia 0.05)
if p_value > 0.05:
    print("Los residuos son normales.")
else:
    print("Los residuos no son normales.")
# Out:
# Valor p:  0.0
# Los residuos no son normales.

# %% [markdown]
# * Como muestra el test de shapiro los datos residuales no son normales

# %%
# Graficar los valores ajustados vs los residuos
plt.scatter(y_pred_test, residual, c='b', s=50, alpha=0.5)

# Graficar una línea horizontal en cero
plt.axhline(y=0, color='r', linestyle='-')

# Etiquetar los ejes y agregar un título
plt.xlabel('Valores ajustados')
plt.ylabel('Residuos')
plt.title('Gráfico Fitted vs Residual')

# Mostrar la gráfica
plt.show()

# %% [markdown]
# * Para el test de Homocedasticidad graficamente verificamos que los datos no se distribuyen aleatoreamente al rededor de cero. Lo que nos indicaria que la regresion lineal no es una buena tecnica

# %%
# Graficar los valores ajustados vs los valores observados
plt.scatter(y_pred_test, y_test, c='b', s=50, alpha=0.5)

# Graficar una línea diagonal desde el punto mínimo al punto máximo
plt.plot([y.min(), y.max()], [y.min(), y.max()], 'k--', lw=2)

# Etiquetar los ejes y agregar un título
plt.xlabel('Valores ajustados')
plt.ylabel('Valores observados')
plt.title('Gráfico Fitted vs Observed')

# Mostrar la gráfica
plt.show()

# %% [markdown]
# * se Observa que los datos no se distribuyen al rededor de la linea, esto nos indica que la regresion lineal multiple no es optima para modelar este dataset
